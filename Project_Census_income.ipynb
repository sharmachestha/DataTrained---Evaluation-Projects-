# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report,confusion_matrix
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('census_income.csv')
df.head()
# Out:
#    Age          Workclass  Fnlwgt   Education  Education_num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         Marital_status          Occupation    Relationship    Race      Sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    Capital_gain  Capital_loss  Hours_per_week  Native_country  Income
# 0             0             0              13   United-States   <=50K
# 1             0             0              40   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40            Cuba   <=50K
# 4             0             0              40   United-States   <=50K

# %%
df.shape
# Out:
# (32560, 15)

# %%
df.columns
# Out:
# Index(['Age', 'Workclass', 'Fnlwgt', 'Education', 'Education_num',
#        'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex',
#        'Capital_gain', 'Capital_loss', 'Hours_per_week', 'Native_country',
#        'Income'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Age                int64
# Workclass         object
# Fnlwgt             int64
# Education         object
# Education_num      int64
# Marital_status    object
# Occupation        object
# Relationship      object
# Race              object
# Sex               object
# Capital_gain       int64
# Capital_loss       int64
# Hours_per_week     int64
# Native_country    object
# Income            object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32560 non-null  int64
#  1   Workclass       32560 non-null  object
#  2   Fnlwgt          32560 non-null  int64
#  3   Education       32560 non-null  object
#  4   Education_num   32560 non-null  int64
#  5   Marital_status  32560 non-null  object
#  6   Occupation      32560 non-null  object
#  7   Relationship    32560 non-null  object
#  8   Race            32560 non-null  object
#  9   Sex             32560 non-null  object
#  10  Capital_gain    32560 non-null  int64
#  11  Capital_loss    32560 non-null  int64
#  12  Hours_per_week  32560 non-null  int64
#  13  Native_country  32560 non-null  object
#  14  Income          32560 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %% [markdown]
# # Summary Statistics

# %%
df.describe()
# Out:
#                 Age        Fnlwgt  Education_num  Capital_gain  Capital_loss  \
# count  32560.000000  3.256000e+04   32560.000000  32560.000000  32560.000000
# mean      38.581634  1.897818e+05      10.080590   1077.615172     87.306511
# std       13.640642  1.055498e+05       2.572709   7385.402999    402.966116
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178315e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783630e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370545e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        Hours_per_week
# count    32560.000000
# mean        40.437469
# std         12.347618
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %% [markdown]
# Observations :-
#
# 1. The mean is more than median for all columns.
# 2. There is large difference between standard deviation and maximum for capital_gain, capital_loss .

# %% [markdown]
# # Exploring Target Variable

# %%
df['Income'].value_counts()
# Out:
#  <=50K    24719
#  >50K      7841
# Name: Income, dtype: int64

# %%
# As we have categorical values in Income column, so, this is a classification problem.

# %% [markdown]
# # Data Visualizations

# %% [markdown]
# To check missing values

# %%
sns.heatmap(df.isnull())

# %% [markdown]
# Obsevations :-
#
# 1. The data has no missing values.

# %% [markdown]
# # Univariate Analysis

# %%
sns.countplot(df['Income'])

# %% [markdown]
# Observations :-
#
# 1. People who have their income less than and equal to fifty thousand dollars are present more in dataset.
# 2. This is a class imbalance problem.

# %%
plt.figure(figsize=(18,12))
sns.set_style('whitegrid')
sns.countplot(x='Income',hue='Workclass',data=df,palette='RdBu_r')

# %% [markdown]
# Observations :-
#
# 1. Highest number of people in private department have income greater than and equal to 50k.
# 2. Lowest number of people in unknown department have income greater than and equal to 50k.

# %%
plt.figure(figsize=(18,12))
#plt.legend(loc="best")
sns.set_style('whitegrid')
sns.countplot(x='Income',hue='Education',data=df,palette='RdBu_r')

# %% [markdown]
# Observations :-
#
# 1. Highest number of bachelors have income greater than and equal to 50k.
# 2. Lowest number 0f 9th pass have income greater than and equal to 50k.
# 3. High number of HS-grad, Masters  and some - college people have income greater than and equal to 50k.
# 4. Very few number of 12th, 11th, 10th and 7th - 8th passed people have income greater than and equal to 50k.
# 5. 0 number of Preschool, 1st - 4th, and 5th - 6th passes people have income greater than and equal to 50k.

# %%
# We will drop the column of Education_num as it is formed by applying grouping on Education column.
df.drop('Education_num',axis=1,inplace=True)

# %%
plt.figure(figsize=(18,12))
#plt.legend(loc="best")
sns.set_style('whitegrid')
sns.countplot(x='Income',hue='Marital_status',data=df,palette='RdBu_r')

# %% [markdown]
# Observations :-
#
# 1. Highest number of married people who have civilian spouse have income greater than and equal to 50k.
# 2. Lowest number of married people who have absent spouse have income greater than and equal to 50k.
# 3. High number of divorced and never married people have income greater than and equal to 50k.
# 4. Very few number of seperated and widowed people have income greater than and equal to 50k.
# 5. 0 number of people who have spouse in armed forces have income greater than and equal to 50k.

# %%
plt.figure(figsize=(18,12))
sns.set_style('whitegrid')
sns.countplot(x='Income',hue='Occupation',data=df,palette='RdBu_r')

# %% [markdown]
# Observations :-
#
# 1. Highest number of executive - managers have income greater than and equal to 50k.
# 2. Lowest number of handler cleaners have income greater than and equal to 50k.
# 3. High number of speciality professors, scalers and crafts repairer have income greater than and equal to 50k.
# 4. Very few number of people in other - services, farmer fishing and unkonwn services have income greater than and equal to 50k.
# 5. 0 number of people in armed forces and private house services have income greater than and equal to 50k.

# %%
#plt.figure(figsize=(18,12))
#plt.legend(loc="best")
sns.set_style('whitegrid')
sns.countplot(x='Income',hue='Relationship',data=df,palette='RdBu_r')

# %% [markdown]
# Obsrvations :-
#
# 1. Highest number of earning people as husbands have income greater than and equal to 50k.
# 2. Lowest number of people who have their own child as an earning member have income greater than and equal to 50k.
# 3. High number of people who have no family have income greater than and equal to 50k.
# 4. Very few number of unmarried people have income greater than and equal to 50k.
# 5. 0 number of people who have their other relatives as an earning member have income greater than and equal to 50k.

# %%
#plt.figure(figsize=(18,12))
#plt.legend(loc="best")
sns.set_style('whitegrid')
sns.countplot(x='Income',hue='Race',data=df,palette='RdBu_r')

# %% [markdown]
# Observations :-
#
# 1. Highest number of white people have income greater than and equal to 50k.
# 2. Lowest number of black people have income greater than and equal to 50k.
# 3. 0 number of Asian-Pac-Islander and Armer-Indian-Eskimo have income greater than and equal to 50k.

# %%
#plt.figure(figsize=(18,12))
#plt.legend(loc="best")
sns.set_style('whitegrid')
sns.countplot(x='Income',hue='Sex',data=df,palette='RdBu_r')

# %% [markdown]
# Observations :-
#
# 1. More number of males have income greater than and equal to 50k as compared to females.

# %%
df_int_types=[]
for i in df.columns:
    if df[i].dtypes == "int64":
        df_int_types.append(i)

# %%
df_int_types
# Out:
# ['Age', 'Fnlwgt', 'Capital_gain', 'Capital_loss', 'Hours_per_week']

# %%
df_str_types=[]
for i in df.columns:
    if df[i].dtypes == "object":
        df_str_types.append(i)

# %%
df_str_types
# Out:
# ['Workclass',
#  'Education',
#  'Marital_status',
#  'Occupation',
#  'Relationship',
#  'Race',
#  'Sex',
#  'Native_country',
#  'Income']

# %%
for value in df_str_types:
    print(df[value].value_counts().sort_index())
# Out:
#  ?                    1836
#  Federal-gov           960
#  Local-gov            2093
#  Never-worked            7
#  Private             22696
#  Self-emp-inc         1116
#  Self-emp-not-inc     2541
#  State-gov            1297
#  Without-pay            14
# Name: Workclass, dtype: int64
#  10th              933
#  11th             1175
#  12th              433
#  1st-4th           168
#  5th-6th           333
#  7th-8th           646
#  9th               514
#  Assoc-acdm       1067
#  Assoc-voc        1382
#  Bachelors        5354
#  Doctorate         413
#  HS-grad         10501
#  Masters          1723
#  Preschool          51
#  Prof-school       576
#  Some-college     7291
# Name: Education, dtype: int64
#  Divorced                  4443
#  Married-AF-spouse           23
#  Married-civ-spouse       14976
#  Married-spouse-absent      418
#  Never-married            10682
#  Separated                 1025
#  Widowed                    993
# Name: Marital_status, dtype: int64
#  ?                    1843
#  Adm-clerical         3769
#  Armed-Forces            9
#  Craft-repair         4099
#  Exec-managerial      4066
#  Farming-fishing       994
#  Handlers-cleaners    1370
#  Machine-op-inspct    2002
#  Other-service        3295
#  Priv-house-serv       149
#  Prof-specialty       4140
#  Protective-serv       649
#  Sales                3650
#  Tech-support          928
#  Transport-moving     1597
# Name: Occupation, dtype: int64
#  Husband           13193
#  Not-in-family      8304
#  Other-relative      981
#  Own-child          5068
#  Unmarried          3446
#  Wife               1568
# Name: Relationship, dtype: int64
#  Amer-Indian-Eskimo      311
#  Asian-Pac-Islander     1039
#  Black                  3124
#  Other                   271
#  White                 27815
# Name: Race, dtype: int64
#  Female    10771
#  Male      21789
# Name: Sex, dtype: int64
#  ?                               583
#  Cambodia                         19
#  Canada                          121
#  China                            75
#  Columbia                         59
#  Cuba                             95
#  Dominican-Republic               70
#  Ecuador                          28
#  El-Salvador                     106
#  England                          90
#  France                           29
#  Germany                         137
#  Greece                           29
#  Guatemala                        64
#  Haiti                            44
#  Holand-Netherlands                1
#  Honduras                         13
#  Hong                             20
#  Hungary                          13
#  India                           100
#  Iran                             43
#  Ireland                          24
#  Italy                            73
#  Jamaica                          81
#  Japan                            62
#  Laos                             18
#  Mexico                          643
#  Nicaragua                        34
#  Outlying-US(Guam-USVI-etc)       14
#  Peru                             31
#  Philippines                     198
#  Poland                           60
#  Portugal                         37
#  Puerto-Rico                     114
#  Scotland                         12
#  South                            80
#  Taiwan                           51
#  Thailand                         18
#  Trinadad&Tobago                  19
#  United-States                 29169
#  Vietnam                          67
#  Yugoslavia                       16
# Name: Native_country, dtype: int64
#  <=50K    24719
#  >50K      7841
# Name: Income, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()
for value in df_str_types:
    df[value]=LE.fit_transform(df[value])
    print(df[value].value_counts().sort_index())
# Out:
# 0     1836
# 1      960
# 2     2093
# 3        7
# 4    22696
# 5     1116
# 6     2541
# 7     1297
# 8       14
# Name: Workclass, dtype: int64
# 0       933
# 1      1175
# 2       433
# 3       168
# 4       333
# 5       646
# 6       514
# 7      1067
# 8      1382
# 9      5354
# 10      413
# 11    10501
# 12     1723
# 13       51
# 14      576
# 15     7291
# Name: Education, dtype: int64
# 0     4443
# 1       23
# 2    14976
# 3      418
# 4    10682
# 5     1025
# 6      993
# Name: Marital_status, dtype: int64
# 0     1843
# 1     3769
# 2        9
# 3     4099
# 4     4066
# 5      994
# 6     1370
# 7     2002
# 8     3295
# 9      149
# 10    4140
# 11     649
# 12    3650
# 13     928
# 14    1597
# Name: Occupation, dtype: int64
# 0    13193
# 1     8304
# 2      981
# 3     5068
# 4     3446
# 5     1568
# Name: Relationship, dtype: int64
# 0      311
# 1     1039
# 2     3124
# 3      271
# 4    27815
# Name: Race, dtype: int64
# 0    10771
# 1    21789
# Name: Sex, dtype: int64
# 0       583
# 1        19
# 2       121
# 3        75
# 4        59
# 5        95
# 6        70
# 7        28
# 8       106
# 9        90
# 10       29
# 11      137
# 12       29
# 13       64
# 14       44
# 15        1
# 16       13
# 17       20
# 18       13
# 19      100
# 20       43
# 21       24
# 22       73
# 23       81
# 24       62
# 25       18
# 26      643
# 27       34
# 28       14
# 29       31
# 30      198
# 31       60
# 32       37
# 33      114
# 34       12
# 35       80
# 36       51
# 37       18
# 38       19
# 39    29169
# 40       67
# 41       16
# Name: Native_country, dtype: int64
# 0    24719
# 1     7841
# Name: Income, dtype: int64

# %%
plt.figure(figsize=(18,12))
sns.set_style('whitegrid')
sns.countplot(x='Income',hue='Native_country',data=df,palette='RdBu_r')

# %% [markdown]
# Observations :-
#
# 1. Highest number of people in United States have income greater than and equal to 50k.
# 2. Lowest number of people in Scotland have income greater than and equal to 50k.
# 3. Less number of people in Cambodia have income greater than and equal to 50k.
# 4. Only United States, Scotland and Cambodia have income greater than and equal to 50k.

# %%
df_int_types=['Age', 'Fnlwgt','Hours_per_week']

# %%
for i in df_int_types:
    sns.distplot(df[i])
    plt.show()

# %% [markdown]
# Observations :-
#
# 1. Age of people is majorly in the range of 20-50 according to census.
# 2. As per census, hours per week given by people for their work is majorly in the range of 38-42.
# 3. The weights on the Current Population Survey (CPS) files is majorly in the range of 200000-400000.

# %%
sns.violinplot(df['Capital_loss'])

# %% [markdown]
# Observations :-
#
# 1. The capital loss of people is majorly 0 as per census.
# 2. High number of people have capital loss in the range of 1500-2000.

# %%
sns.violinplot(df['Capital_gain'])

# %% [markdown]
# Observations :-
#
# 1. The capital gain of people is majorly 0 as per census.
# 2. High number of people have capital gain in the range of 0-20000.

# %%
dfcorr=df.corr()
dfcorr
# Out:
#                      Age  Workclass    Fnlwgt  Education  Marital_status  \
# Age             1.000000   0.003786 -0.076646  -0.010508       -0.266292
# Workclass       0.003786   1.000000 -0.016587   0.023537       -0.064798
# Fnlwgt         -0.076646  -0.016587  1.000000  -0.028156        0.028184
# Education      -0.010508   0.023537 -0.028156   1.000000       -0.038398
# Marital_status -0.266292  -0.064798  0.028184  -0.038398        1.000000
# Occupation     -0.020946   0.255004  0.001554  -0.021274       -0.009617
# Relationship   -0.263698  -0.090449  0.008922  -0.010879        0.185461
# Race            0.028718   0.049720 -0.021278   0.014135       -0.068025
# Sex             0.088832   0.095942  0.026882  -0.027349       -0.129337
# Capital_gain    0.077674   0.033828  0.000437   0.030047       -0.043398
# Capital_loss    0.057775   0.012231 -0.010259   0.016744       -0.034182
# Hours_per_week  0.068756   0.138974 -0.018770   0.055510       -0.190521
# Native_country -0.001151  -0.007710 -0.051957   0.064291       -0.023827
# Income          0.234039   0.051645 -0.009481   0.079311       -0.199295
#
#                 Occupation  Relationship      Race       Sex  Capital_gain  \
# Age              -0.020946     -0.263698  0.028718  0.088832      0.077674
# Workclass         0.255004     -0.090449  0.049720  0.095942      0.033828
# Fnlwgt            0.001554      0.008922 -0.021278  0.026882      0.000437
# Education        -0.021274     -0.010879  0.014135 -0.027349      0.030047
# Marital_status   -0.009617      0.185461 -0.068025 -0.129337     -0.043398
# Occupation        1.000000     -0.075620  0.006779  0.080328      0.025511
# Relationship     -0.075620      1.000000 -0.116052 -0.582453     -0.057918
# Race              0.006779     -0.116052  1.000000  0.087197      0.011143
# Sex               0.080328     -0.582453  0.087197  1.000000      0.048477
# Capital_gain      0.025511     -0.057918  0.011143  0.048477      1.000000
# Capital_loss      0.017979     -0.061064  0.018902  0.045572     -0.031614
# Hours_per_week    0.080384     -0.248975  0.041910  0.229312      0.078409
# Native_country   -0.012532     -0.005504  0.137849 -0.008125     -0.001984
# Income            0.075448     -0.250924  0.071853  0.215995      0.223333
#
#                 Capital_loss  Hours_per_week  Native_country    Income
# Age                 0.057775        0.068756       -0.001151  0.234039
# Workclass           0.012231        0.138974       -0.007710  0.051645
# Fnlwgt             -0.010259       -0.018770       -0.051957 -0.009481
# Education           0.016744        0.055510        0.064291  0.079311
# Marital_status     -0.034182       -0.190521       -0.023827 -0.199295
# Occupation          0.017979        0.080384       -0.012532  0.075448
# Relationship       -0.061064       -0.248975       -0.005504 -0.250924
# Race                0.018902        0.041910        0.137849  0.071853
# Sex                 0.045572        0.229312       -0.008125  0.215995
# Capital_gain       -0.031614        0.078409       -0.001984  0.223333
# Capital_loss        1.000000        0.054256        0.000420  0.150523
# Hours_per_week      0.054256        1.000000       -0.002671  0.229690
# Native_country      0.000420       -0.002671        1.000000  0.015845
# Income              0.150523        0.229690        0.015845  1.000000

# %%
# Multivariate Analysis
plt.figure(figsize=(15,13))
sns.heatmap(dfcorr,cmap='YlGnBu',annot=True)

# %% [markdown]
# Observations :-
#
# 1. Income is highly positively correlated to Age.
# 2. Age is highly negatively correlated to Marital Status.
# 3. Marital Status is highly positively correlated to Relationship.
# 4. Marital Status is highly negatively correlated to Income

# %% [markdown]
# # Plotting Outliers

# %%
df.shape
# Out:
# (32560, 14)

# %%
df.plot(kind='box',subplots=True,layout=(1,14),sharex=False,fontsize=1,figsize=(18,12))
# Out:
# Age                  AxesSubplot(0.125,0.125;0.0466867x0.755)
# Workclass         AxesSubplot(0.181024,0.125;0.0466867x0.755)
# Fnlwgt            AxesSubplot(0.237048,0.125;0.0466867x0.755)
# Education         AxesSubplot(0.293072,0.125;0.0466867x0.755)
# Marital_status    AxesSubplot(0.349096,0.125;0.0466867x0.755)
# Occupation         AxesSubplot(0.40512,0.125;0.0466867x0.755)
# Relationship      AxesSubplot(0.461145,0.125;0.0466867x0.755)
# Race              AxesSubplot(0.517169,0.125;0.0466867x0.755)
# Sex               AxesSubplot(0.573193,0.125;0.0466867x0.755)
# Capital_gain      AxesSubplot(0.629217,0.125;0.0466867x0.755)
# Capital_loss      AxesSubplot(0.685241,0.125;0.0466867x0.755)
# Hours_per_week    AxesSubplot(0.741265,0.125;0.0466867x0.755)
# Native_country    AxesSubplot(0.797289,0.125;0.0466867x0.755)
# Income            AxesSubplot(0.853313,0.125;0.0466867x0.755)
# dtype: object

# %% [markdown]
# Observations :-
#
# 1. Age, Workclass, Fnlwgt, Education, Race, Capital_gain, Capital_loss, Hours_per_week, Native_country
# and Income have outliers.

# %%
df.columns
# Out:
# Index(['Age', 'Workclass', 'Fnlwgt', 'Education', 'Marital_status',
#        'Occupation', 'Relationship', 'Race', 'Sex', 'Capital_gain',
#        'Capital_loss', 'Hours_per_week', 'Native_country', 'Income'],
#       dtype='object')

# %% [markdown]
# # Removing Outliers

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))

# %%
z
# Out:
# array([[0.83709708, 1.46388339, 1.0087417 , ..., 2.22212013, 0.29157343,
#         0.5632099 ],
#        [0.04264043, 0.09012148, 0.24504633, ..., 0.03542999, 0.29157343,
#         0.5632099 ],
#        [1.05703146, 0.09012148, 0.42576955, ..., 0.03542999, 0.29157343,
#         0.5632099 ],
#        ...,
#        [1.42358875, 0.09012148, 0.3588108 , ..., 0.03542999, 0.29157343,
#         0.5632099 ],
#        [1.21562378, 0.09012148, 0.11092744, ..., 1.65520046, 0.29157343,
#         0.5632099 ],
#        [0.98372   , 0.77700244, 0.92986178, ..., 0.03542999, 0.29157343,
#         1.77553698]])

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([    3,     9,    10, ..., 32532, 32550, 32552], dtype=int64), array([12, 11,  7, ...,  7,  7,  7], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]

# %%
df_new.shape
# Out:
# (27561, 14)

# %%
df.shape
# Out:
# (32560, 14)

# %%
df=df_new

# %%
# 4999 rows are removed as outliers.

# %%
((32560-27561)/32560)*100
# Out:
# 15.353194103194104

# %% [markdown]
# # To check Skewness

# %%
df.plot(kind='density',subplots=True,layout=(3,5),sharex=False,fontsize=1,figsize=(18,12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001A8C7E6A0C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8C6CA4988>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8C6D05388>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8C6D50F88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8C6D51548>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001A8C73AE648>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8C75066C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8C753F7C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8C754A3C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8C7583588>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001A8C8239B08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8C8270B88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8C82A9C88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8C86D0DC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A8C8708EC8>]],
#       dtype=object)

# %% [markdown]
# Observations :-
#
# 1. Fnlwgt, Relationship, Capital_gain, Capital_loss and Income are right skewed.
# 2. Workclass, Education, Race, Sex and Native_country are left skewed.

# %%
df.skew()
# Out:
# Age                0.481894
# Workclass         -0.740966
# Fnlwgt             0.624658
# Education         -0.944964
# Marital_status    -0.042647
# Occupation         0.131546
# Relationship       0.752376
# Race              -2.589087
# Sex               -0.687149
# Capital_gain       4.946239
# Capital_loss      29.402904
# Hours_per_week    -0.355987
# Native_country    -5.229001
# Income             1.331757
# dtype: float64

# %%
df_rs=['Fnlwgt', 'Relationship', 'Capital_gain', 'Capital_loss']
for val in df_rs:
    if df.skew().loc[val]>0.55:
        df[val]=np.sqrt(df[val])

# %%
df.skew()
# Out:
# Age                0.481894
# Workclass         -0.740966
# Fnlwgt            -0.113821
# Education         -0.944964
# Marital_status    -0.042647
# Occupation         0.131546
# Relationship       0.119690
# Race              -2.589087
# Sex               -0.687149
# Capital_gain       3.694117
# Capital_loss      26.340962
# Hours_per_week    -0.355987
# Native_country    -5.229001
# Income             1.331757
# dtype: float64

# %%
df_rs=['Capital_gain', 'Capital_loss']
for val in df_rs:
    if df.skew().loc[val]>0.55:
        df[val]=np.sqrt(df[val])

# %%
df.skew()
# Out:
# Age                0.481894
# Workclass         -0.740966
# Fnlwgt            -0.113821
# Education         -0.944964
# Marital_status    -0.042647
# Occupation         0.131546
# Relationship       0.119690
# Race              -2.589087
# Sex               -0.687149
# Capital_gain       3.254481
# Capital_loss      25.196908
# Hours_per_week    -0.355987
# Native_country    -5.229001
# Income             1.331757
# dtype: float64

# %%
df.isnull().sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %% [markdown]
# # Dropping of Columns

# %%
# We will drop the column of Capital_loss as it's skewness is very high, i.e, 25.13.
df.drop('Capital_loss',axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['Age', 'Workclass', 'Fnlwgt', 'Education', 'Marital_status',
#        'Occupation', 'Relationship', 'Race', 'Sex', 'Capital_gain',
#        'Hours_per_week', 'Native_country', 'Income'],
#       dtype='object')

# %% [markdown]
# # Train Test Split

# %%
x=df[['Age', 'Workclass', 'Fnlwgt', 'Education', 
       'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex',
       'Capital_gain', 'Hours_per_week', 'Native_country']]

y=df['Income']

# %% [markdown]
# # Solution of Class Imbalance

# %%
import imblearn

# %%
from imblearn.over_sampling import SMOTE

# %%
SM=SMOTE()

# %%
x_over,y_over=SM.fit_resample(x,y)

# %%
y_over.value_counts()
y_over.head()
y=pd.DataFrame(y_over,columns=['Income'])
y.head()
x=pd.DataFrame(x_over,columns=['Age', 'Workclass', 'Fnlwgt', 'Education', 
       'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex',
       'Capital_gain', 'Hours_per_week', 'Native_country'])

# %%
df=pd.concat((x,y),axis=1)

# %%
df.shape
# Out:
# (42836, 13)

# %%
df['Income'].value_counts()
# Out:
# 1    21418
# 0    21418
# Name: Income, dtype: int64

# %% [markdown]
# # Scaling of Data

# %%
from sklearn.preprocessing import StandardScaler
SC=StandardScaler()
x=SC.fit_transform(x)

# %%
x
# Out:
# array([[ 0.78314373,  1.61723345, -1.12704614, ..., -0.37272764,
#         -2.68027823,  0.17643537],
#        [-0.17265391,  0.13592071,  0.42929899, ..., -0.37272764,
#         -0.14254108,  0.17643537],
#        [ 1.02209314,  0.13592071,  0.60733081, ..., -0.37272764,
#         -0.14254108,  0.17643537],
#        ...,
#        [ 1.02209314,  0.13592071,  1.09145817, ..., -0.37272764,
#          0.89135184,  0.17643537],
#        [-0.0930041 ,  0.13592071,  0.24727939, ..., -0.37272764,
#         -0.14254108,  0.17643537],
#        [ 0.1459453 ,  0.87657708, -1.18942209, ..., -0.37272764,
#          1.2673129 ,  0.17643537]])

# %%
x=pd.DataFrame(x)

# %%
x
# Out:
#               0         1         2         3         4         5         6  \
# 0      0.783144  1.617233 -1.127046 -0.400081 -0.283906 -0.632847 -0.894774
# 1     -0.172654  0.135921  0.429299  0.183028 -1.801802 -0.145654  0.370002
# 2      1.022093  0.135921  0.607331 -2.732515 -0.283906 -0.145654 -0.894774
# 3     -0.252304  0.135921  1.041113  0.474582 -0.283906 -0.632847  1.933351
# 4      0.703494  0.135921 -0.138749 -1.274744  0.475042  0.341539  0.370002
# ...         ...       ...       ...       ...       ...       ...       ...
# 42831 -0.730203  0.135921  1.545058  0.183028 -0.283906 -0.876444 -0.894774
# 42832  0.703494 -1.345392  0.304051  0.474582 -0.283906  0.828732 -0.894774
# 42833  1.022093  0.135921  1.091458  0.183028 -0.283906 -0.632847 -0.894774
# 42834 -0.093004  0.135921  0.247279 -3.024069 -0.283906 -0.876444 -0.894774
# 42835  0.145945  0.876577 -1.189422  1.349245 -0.283906 -0.632847 -0.894774
#
#               7         8         9        10        11
# 0      0.325975  0.660233 -0.372728 -2.680278  0.176435
# 1      0.325975  0.660233 -0.372728 -0.142541  0.176435
# 2     -3.270074  0.660233 -0.372728 -0.142541  0.176435
# 3      0.325975 -1.514617 -0.372728 -0.142541  0.176435
# 4     -3.270074 -1.514617 -0.372728 -2.398307 -6.277005
# ...         ...       ...       ...       ...       ...
# 42831  0.325975  0.660233 -0.372728 -0.142541  0.176435
# 42832  0.325975  0.660233 -0.372728 -0.142541  0.176435
# 42833  0.325975  0.660233 -0.372728  0.891352  0.176435
# 42834  0.325975  0.660233 -0.372728 -0.142541  0.176435
# 42835  0.325975  0.660233 -0.372728  1.267313  0.176435
#
# [42836 rows x 12 columns]

# %%
x.columns=['Age', 'Workclass', 'Fnlwgt', 'Education',
       'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex',
       'Capital_gain', 'Hours_per_week', 'Native_country']

# %%
x.head()
# Out:
#         Age  Workclass    Fnlwgt  Education  Marital_status  Occupation  \
# 0  0.783144   1.617233 -1.127046  -0.400081       -0.283906   -0.632847
# 1 -0.172654   0.135921  0.429299   0.183028       -1.801802   -0.145654
# 2  1.022093   0.135921  0.607331  -2.732515       -0.283906   -0.145654
# 3 -0.252304   0.135921  1.041113   0.474582       -0.283906   -0.632847
# 4  0.703494   0.135921 -0.138749  -1.274744        0.475042    0.341539
#
#    Relationship      Race       Sex  Capital_gain  Hours_per_week  \
# 0     -0.894774  0.325975  0.660233     -0.372728       -2.680278
# 1      0.370002  0.325975  0.660233     -0.372728       -0.142541
# 2     -0.894774 -3.270074  0.660233     -0.372728       -0.142541
# 3      1.933351  0.325975 -1.514617     -0.372728       -0.142541
# 4      0.370002 -3.270074 -1.514617     -0.372728       -2.398307
#
#    Native_country
# 0        0.176435
# 1        0.176435
# 2        0.176435
# 3        0.176435
# 4       -6.277005

# %%
x.head()
# Out:
#         Age  Workclass    Fnlwgt  Education  Marital_status  Occupation  \
# 0  0.783144   1.617233 -1.127046  -0.400081       -0.283906   -0.632847
# 1 -0.172654   0.135921  0.429299   0.183028       -1.801802   -0.145654
# 2  1.022093   0.135921  0.607331  -2.732515       -0.283906   -0.145654
# 3 -0.252304   0.135921  1.041113   0.474582       -0.283906   -0.632847
# 4  0.703494   0.135921 -0.138749  -1.274744        0.475042    0.341539
#
#    Relationship      Race       Sex  Capital_gain  Hours_per_week  \
# 0     -0.894774  0.325975  0.660233     -0.372728       -2.680278
# 1      0.370002  0.325975  0.660233     -0.372728       -0.142541
# 2     -0.894774 -3.270074  0.660233     -0.372728       -0.142541
# 3      1.933351  0.325975 -1.514617     -0.372728       -0.142541
# 4      0.370002 -3.270074 -1.514617     -0.372728       -2.398307
#
#    Native_country
# 0        0.176435
# 1        0.176435
# 2        0.176435
# 3        0.176435
# 4       -6.277005

# %% [markdown]
# # Algorithms

# %%
from sklearn.model_selection import train_test_split
maxAccu=0
maxRS=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.22,random_state=i)
    lm=LogisticRegression()
    lm.fit(x_train,y_train)
    pred=lm.predict(x_test)
    print('Accuracy score of Logistic Regression','is:')
    accu_score=accuracy_score(y_test,pred)
    print(accuracy_score(y_test,pred))
    print(confusion_matrix(y_test,pred))
    print(classification_report(y_test,pred))
    if accu_score>maxAccu:
        maxAccu=accu_score
        maxRS=i
        
print("Best accuracy is",maxAccu,"on Random_state",maxRS)
# Out:
# Accuracy score of Logistic Regression is:
# 0.7523344651952462
# [[3259 1534]
#  [ 800 3831]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.68      0.74      4793
#            1       0.71      0.83      0.77      4631
#
#     accuracy                           0.75      9424
#    macro avg       0.76      0.75      0.75      9424
# weighted avg       0.76      0.75      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7513794567062818
# [[3177 1515]
#  [ 828 3904]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.68      0.73      4692
#            1       0.72      0.83      0.77      4732
#
#     accuracy                           0.75      9424
#    macro avg       0.76      0.75      0.75      9424
# weighted avg       0.76      0.75      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7568972835314092
# [[3215 1496]
#  [ 795 3918]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.68      0.74      4711
#            1       0.72      0.83      0.77      4713
#
#     accuracy                           0.76      9424
#    macro avg       0.76      0.76      0.76      9424
# weighted avg       0.76      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7590195246179966
# [[3290 1544]
#  [ 727 3863]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.68      0.74      4834
#            1       0.71      0.84      0.77      4590
#
#     accuracy                           0.76      9424
#    macro avg       0.77      0.76      0.76      9424
# weighted avg       0.77      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7571095076400679
# [[3249 1478]
#  [ 811 3886]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.69      0.74      4727
#            1       0.72      0.83      0.77      4697
#
#     accuracy                           0.76      9424
#    macro avg       0.76      0.76      0.76      9424
# weighted avg       0.76      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.756260611205433
# [[3196 1501]
#  [ 796 3931]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.68      0.74      4697
#            1       0.72      0.83      0.77      4727
#
#     accuracy                           0.76      9424
#    macro avg       0.76      0.76      0.75      9424
# weighted avg       0.76      0.76      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7601867572156197
# [[3268 1446]
#  [ 814 3896]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.69      0.74      4714
#            1       0.73      0.83      0.78      4710
#
#     accuracy                           0.76      9424
#    macro avg       0.76      0.76      0.76      9424
# weighted avg       0.76      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7536078098471987
# [[3133 1499]
#  [ 823 3969]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.68      0.73      4632
#            1       0.73      0.83      0.77      4792
#
#     accuracy                           0.75      9424
#    macro avg       0.76      0.75      0.75      9424
# weighted avg       0.76      0.75      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7618845500848896
# [[3242 1448]
#  [ 796 3938]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.69      0.74      4690
#            1       0.73      0.83      0.78      4734
#
#     accuracy                           0.76      9424
#    macro avg       0.77      0.76      0.76      9424
# weighted avg       0.77      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7538200339558574
# [[3216 1534]
#  [ 786 3888]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.68      0.73      4750
#            1       0.72      0.83      0.77      4674
#
#     accuracy                           0.75      9424
#    macro avg       0.76      0.75      0.75      9424
# weighted avg       0.76      0.75      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7595500848896435
# [[3231 1456]
#  [ 810 3927]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.69      0.74      4687
#            1       0.73      0.83      0.78      4737
#
#     accuracy                           0.76      9424
#    macro avg       0.76      0.76      0.76      9424
# weighted avg       0.76      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7543505942275043
# [[3294 1534]
#  [ 781 3815]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.68      0.74      4828
#            1       0.71      0.83      0.77      4596
#
#     accuracy                           0.75      9424
#    macro avg       0.76      0.76      0.75      9424
# weighted avg       0.76      0.75      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7561544991511036
# [[3197 1512]
#  [ 786 3929]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.68      0.74      4709
#            1       0.72      0.83      0.77      4715
#
#     accuracy                           0.76      9424
#    macro avg       0.76      0.76      0.75      9424
# weighted avg       0.76      0.76      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.754881154499151
# [[3266 1499]
#  [ 811 3848]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.69      0.74      4765
#            1       0.72      0.83      0.77      4659
#
#     accuracy                           0.75      9424
#    macro avg       0.76      0.76      0.75      9424
# weighted avg       0.76      0.75      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7529711375212224
# [[3221 1499]
#  [ 829 3875]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.68      0.73      4720
#            1       0.72      0.82      0.77      4704
#
#     accuracy                           0.75      9424
#    macro avg       0.76      0.75      0.75      9424
# weighted avg       0.76      0.75      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7602928692699491
# [[3250 1464]
#  [ 795 3915]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.69      0.74      4714
#            1       0.73      0.83      0.78      4710
#
#     accuracy                           0.76      9424
#    macro avg       0.77      0.76      0.76      9424
# weighted avg       0.77      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.756260611205433
# [[3228 1508]
#  [ 789 3899]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.68      0.74      4736
#            1       0.72      0.83      0.77      4688
#
#     accuracy                           0.76      9424
#    macro avg       0.76      0.76      0.76      9424
# weighted avg       0.76      0.76      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7631578947368421
# [[3250 1409]
#  [ 823 3942]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.70      0.74      4659
#            1       0.74      0.83      0.78      4765
#
#     accuracy                           0.76      9424
#    macro avg       0.77      0.76      0.76      9424
# weighted avg       0.77      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7538200339558574
# [[3275 1493]
#  [ 827 3829]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.69      0.74      4768
#            1       0.72      0.82      0.77      4656
#
#     accuracy                           0.75      9424
#    macro avg       0.76      0.75      0.75      9424
# weighted avg       0.76      0.75      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7479838709677419
# [[3168 1541]
#  [ 834 3881]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.67      0.73      4709
#            1       0.72      0.82      0.77      4715
#
#     accuracy                           0.75      9424
#    macro avg       0.75      0.75      0.75      9424
# weighted avg       0.75      0.75      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7531833616298812
# [[3215 1476]
#  [ 850 3883]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.69      0.73      4691
#            1       0.72      0.82      0.77      4733
#
#     accuracy                           0.75      9424
#    macro avg       0.76      0.75      0.75      9424
# weighted avg       0.76      0.75      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7479838709677419
# [[3195 1514]
#  [ 861 3854]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.68      0.73      4709
#            1       0.72      0.82      0.76      4715
#
#     accuracy                           0.75      9424
#    macro avg       0.75      0.75      0.75      9424
# weighted avg       0.75      0.75      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7518039049235993
# [[3178 1503]
#  [ 836 3907]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.68      0.73      4681
#            1       0.72      0.82      0.77      4743
#
#     accuracy                           0.75      9424
#    macro avg       0.76      0.75      0.75      9424
# weighted avg       0.76      0.75      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7597623089983022
# [[3194 1486]
#  [ 778 3966]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.68      0.74      4680
#            1       0.73      0.84      0.78      4744
#
#     accuracy                           0.76      9424
#    macro avg       0.77      0.76      0.76      9424
# weighted avg       0.77      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7544567062818336
# [[3236 1493]
#  [ 821 3874]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.68      0.74      4729
#            1       0.72      0.83      0.77      4695
#
#     accuracy                           0.75      9424
#    macro avg       0.76      0.75      0.75      9424
# weighted avg       0.76      0.75      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7546689303904923
# [[3154 1503]
#  [ 809 3958]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.68      0.73      4657
#            1       0.72      0.83      0.77      4767
#
#     accuracy                           0.75      9424
#    macro avg       0.76      0.75      0.75      9424
# weighted avg       0.76      0.75      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7594439728353141
# [[3221 1456]
#  [ 811 3936]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.69      0.74      4677
#            1       0.73      0.83      0.78      4747
#
#     accuracy                           0.76      9424
#    macro avg       0.76      0.76      0.76      9424
# weighted avg       0.76      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.754562818336163
# [[3270 1530]
#  [ 783 3841]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.68      0.74      4800
#            1       0.72      0.83      0.77      4624
#
#     accuracy                           0.75      9424
#    macro avg       0.76      0.76      0.75      9424
# weighted avg       0.76      0.75      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7535016977928692
# [[3192 1519]
#  [ 804 3909]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.68      0.73      4711
#            1       0.72      0.83      0.77      4713
#
#     accuracy                           0.75      9424
#    macro avg       0.76      0.75      0.75      9424
# weighted avg       0.76      0.75      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7511672325976231
# [[3210 1530]
#  [ 815 3869]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.68      0.73      4740
#            1       0.72      0.83      0.77      4684
#
#     accuracy                           0.75      9424
#    macro avg       0.76      0.75      0.75      9424
# weighted avg       0.76      0.75      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7550933786078099
# [[3165 1531]
#  [ 777 3951]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.67      0.73      4696
#            1       0.72      0.84      0.77      4728
#
#     accuracy                           0.76      9424
#    macro avg       0.76      0.75      0.75      9424
# weighted avg       0.76      0.76      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7476655348047538
# [[3196 1540]
#  [ 838 3850]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.67      0.73      4736
#            1       0.71      0.82      0.76      4688
#
#     accuracy                           0.75      9424
#    macro avg       0.75      0.75      0.75      9424
# weighted avg       0.75      0.75      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7589134125636672
# [[3217 1502]
#  [ 770 3935]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.68      0.74      4719
#            1       0.72      0.84      0.78      4705
#
#     accuracy                           0.76      9424
#    macro avg       0.77      0.76      0.76      9424
# weighted avg       0.77      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7504244482173175
# [[3247 1573]
#  [ 779 3825]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.67      0.73      4820
#            1       0.71      0.83      0.76      4604
#
#     accuracy                           0.75      9424
#    macro avg       0.76      0.75      0.75      9424
# weighted avg       0.76      0.75      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7624151103565365
# [[3262 1491]
#  [ 748 3923]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.69      0.74      4753
#            1       0.72      0.84      0.78      4671
#
#     accuracy                           0.76      9424
#    macro avg       0.77      0.76      0.76      9424
# weighted avg       0.77      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7585950764006791
# [[3164 1479]
#  [ 796 3985]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.68      0.74      4643
#            1       0.73      0.83      0.78      4781
#
#     accuracy                           0.76      9424
#    macro avg       0.76      0.76      0.76      9424
# weighted avg       0.76      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7632640067911715
# [[3211 1469]
#  [ 762 3982]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.69      0.74      4680
#            1       0.73      0.84      0.78      4744
#
#     accuracy                           0.76      9424
#    macro avg       0.77      0.76      0.76      9424
# weighted avg       0.77      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7570033955857386
# [[3261 1488]
#  [ 802 3873]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.69      0.74      4749
#            1       0.72      0.83      0.77      4675
#
#     accuracy                           0.76      9424
#    macro avg       0.76      0.76      0.76      9424
# weighted avg       0.76      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.756578947368421
# [[3172 1456]
#  [ 838 3958]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.69      0.73      4628
#            1       0.73      0.83      0.78      4796
#
#     accuracy                           0.76      9424
#    macro avg       0.76      0.76      0.75      9424
# weighted avg       0.76      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7547750424448217
# [[3190 1474]
#  [ 837 3923]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.68      0.73      4664
#            1       0.73      0.82      0.77      4760
#
#     accuracy                           0.75      9424
#    macro avg       0.76      0.75      0.75      9424
# weighted avg       0.76      0.75      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7625212224108658
# [[3273 1464]
#  [ 774 3913]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.69      0.75      4737
#            1       0.73      0.83      0.78      4687
#
#     accuracy                           0.76      9424
#    macro avg       0.77      0.76      0.76      9424
# weighted avg       0.77      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.761141765704584
# [[3250 1465]
#  [ 786 3923]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.69      0.74      4715
#            1       0.73      0.83      0.78      4709
#
#     accuracy                           0.76      9424
#    macro avg       0.77      0.76      0.76      9424
# weighted avg       0.77      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7531833616298812
# [[3252 1509]
#  [ 817 3846]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.68      0.74      4761
#            1       0.72      0.82      0.77      4663
#
#     accuracy                           0.75      9424
#    macro avg       0.76      0.75      0.75      9424
# weighted avg       0.76      0.75      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7549872665534805
# [[3186 1457]
#  [ 852 3929]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.69      0.73      4643
#            1       0.73      0.82      0.77      4781
#
#     accuracy                           0.75      9424
#    macro avg       0.76      0.75      0.75      9424
# weighted avg       0.76      0.75      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7503183361629882
# [[3213 1566]
#  [ 787 3858]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.67      0.73      4779
#            1       0.71      0.83      0.77      4645
#
#     accuracy                           0.75      9424
#    macro avg       0.76      0.75      0.75      9424
# weighted avg       0.76      0.75      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7661290322580645
# [[3211 1411]
#  [ 793 4009]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.69      0.74      4622
#            1       0.74      0.83      0.78      4802
#
#     accuracy                           0.77      9424
#    macro avg       0.77      0.76      0.76      9424
# weighted avg       0.77      0.77      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7540322580645161
# [[3161 1486]
#  [ 832 3945]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.68      0.73      4647
#            1       0.73      0.83      0.77      4777
#
#     accuracy                           0.75      9424
#    macro avg       0.76      0.75      0.75      9424
# weighted avg       0.76      0.75      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7495755517826825
# [[3219 1547]
#  [ 813 3845]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.68      0.73      4766
#            1       0.71      0.83      0.77      4658
#
#     accuracy                           0.75      9424
#    macro avg       0.76      0.75      0.75      9424
# weighted avg       0.76      0.75      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7568972835314092
# [[3134 1499]
#  [ 792 3999]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.68      0.73      4633
#            1       0.73      0.83      0.78      4791
#
#     accuracy                           0.76      9424
#    macro avg       0.76      0.76      0.75      9424
# weighted avg       0.76      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7566850594227504
# [[3174 1475]
#  [ 818 3957]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.68      0.73      4649
#            1       0.73      0.83      0.78      4775
#
#     accuracy                           0.76      9424
#    macro avg       0.76      0.76      0.75      9424
# weighted avg       0.76      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7625212224108658
# [[3307 1459]
#  [ 779 3879]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.69      0.75      4766
#            1       0.73      0.83      0.78      4658
#
#     accuracy                           0.76      9424
#    macro avg       0.77      0.76      0.76      9424
# weighted avg       0.77      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7561544991511036
# [[3223 1488]
#  [ 810 3903]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.68      0.74      4711
#            1       0.72      0.83      0.77      4713
#
#     accuracy                           0.76      9424
#    macro avg       0.76      0.76      0.75      9424
# weighted avg       0.76      0.76      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7522283531409168
# [[3278 1547]
#  [ 788 3811]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.68      0.74      4825
#            1       0.71      0.83      0.77      4599
#
#     accuracy                           0.75      9424
#    macro avg       0.76      0.75      0.75      9424
# weighted avg       0.76      0.75      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7532894736842105
# [[3281 1549]
#  [ 776 3818]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.68      0.74      4830
#            1       0.71      0.83      0.77      4594
#
#     accuracy                           0.75      9424
#    macro avg       0.76      0.76      0.75      9424
# weighted avg       0.76      0.75      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7632640067911715
# [[3255 1441]
#  [ 790 3938]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.69      0.74      4696
#            1       0.73      0.83      0.78      4728
#
#     accuracy                           0.76      9424
#    macro avg       0.77      0.76      0.76      9424
# weighted avg       0.77      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7588073005093379
# [[3220 1453]
#  [ 820 3931]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.69      0.74      4673
#            1       0.73      0.83      0.78      4751
#
#     accuracy                           0.76      9424
#    macro avg       0.76      0.76      0.76      9424
# weighted avg       0.76      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7589134125636672
# [[3264 1515]
#  [ 757 3888]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.68      0.74      4779
#            1       0.72      0.84      0.77      4645
#
#     accuracy                           0.76      9424
#    macro avg       0.77      0.76      0.76      9424
# weighted avg       0.77      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7543505942275043
# [[3246 1541]
#  [ 774 3863]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.68      0.74      4787
#            1       0.71      0.83      0.77      4637
#
#     accuracy                           0.75      9424
#    macro avg       0.76      0.76      0.75      9424
# weighted avg       0.76      0.75      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7547750424448217
# [[3197 1482]
#  [ 829 3916]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.68      0.73      4679
#            1       0.73      0.83      0.77      4745
#
#     accuracy                           0.75      9424
#    macro avg       0.76      0.75      0.75      9424
# weighted avg       0.76      0.75      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7593378607809848
# [[3248 1465]
#  [ 803 3908]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.69      0.74      4713
#            1       0.73      0.83      0.78      4711
#
#     accuracy                           0.76      9424
#    macro avg       0.76      0.76      0.76      9424
# weighted avg       0.76      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7653862478777589
# [[3154 1440]
#  [ 771 4059]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.69      0.74      4594
#            1       0.74      0.84      0.79      4830
#
#     accuracy                           0.77      9424
#    macro avg       0.77      0.76      0.76      9424
# weighted avg       0.77      0.77      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7597623089983022
# [[3171 1484]
#  [ 780 3989]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.68      0.74      4655
#            1       0.73      0.84      0.78      4769
#
#     accuracy                           0.76      9424
#    macro avg       0.77      0.76      0.76      9424
# weighted avg       0.77      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7536078098471987
# [[3195 1493]
#  [ 829 3907]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.68      0.73      4688
#            1       0.72      0.82      0.77      4736
#
#     accuracy                           0.75      9424
#    macro avg       0.76      0.75      0.75      9424
# weighted avg       0.76      0.75      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7567911714770797
# [[3238 1511]
#  [ 781 3894]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.68      0.74      4749
#            1       0.72      0.83      0.77      4675
#
#     accuracy                           0.76      9424
#    macro avg       0.76      0.76      0.76      9424
# weighted avg       0.76      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7640067911714771
# [[3358 1456]
#  [ 768 3842]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.70      0.75      4814
#            1       0.73      0.83      0.78      4610
#
#     accuracy                           0.76      9424
#    macro avg       0.77      0.77      0.76      9424
# weighted avg       0.77      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7630517826825127
# [[3210 1448]
#  [ 785 3981]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.69      0.74      4658
#            1       0.73      0.84      0.78      4766
#
#     accuracy                           0.76      9424
#    macro avg       0.77      0.76      0.76      9424
# weighted avg       0.77      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7579584040747029
# [[3271 1485]
#  [ 796 3872]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.69      0.74      4756
#            1       0.72      0.83      0.77      4668
#
#     accuracy                           0.76      9424
#    macro avg       0.76      0.76      0.76      9424
# weighted avg       0.76      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7602928692699491
# [[3207 1427]
#  [ 832 3958]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.69      0.74      4634
#            1       0.74      0.83      0.78      4790
#
#     accuracy                           0.76      9424
#    macro avg       0.76      0.76      0.76      9424
# weighted avg       0.76      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7529711375212224
# [[3219 1499]
#  [ 829 3877]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.68      0.73      4718
#            1       0.72      0.82      0.77      4706
#
#     accuracy                           0.75      9424
#    macro avg       0.76      0.75      0.75      9424
# weighted avg       0.76      0.75      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7559422750424448
# [[3228 1490]
#  [ 810 3896]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.68      0.74      4718
#            1       0.72      0.83      0.77      4706
#
#     accuracy                           0.76      9424
#    macro avg       0.76      0.76      0.75      9424
# weighted avg       0.76      0.76      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7560483870967742
# [[3215 1503]
#  [ 796 3910]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.68      0.74      4718
#            1       0.72      0.83      0.77      4706
#
#     accuracy                           0.76      9424
#    macro avg       0.76      0.76      0.75      9424
# weighted avg       0.76      0.76      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7589134125636672
# [[3189 1460]
#  [ 812 3963]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.69      0.74      4649
#            1       0.73      0.83      0.78      4775
#
#     accuracy                           0.76      9424
#    macro avg       0.76      0.76      0.76      9424
# weighted avg       0.76      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7523344651952462
# [[3194 1473]
#  [ 861 3896]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.68      0.73      4667
#            1       0.73      0.82      0.77      4757
#
#     accuracy                           0.75      9424
#    macro avg       0.76      0.75      0.75      9424
# weighted avg       0.76      0.75      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7505305602716469
# [[3200 1486]
#  [ 865 3873]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.68      0.73      4686
#            1       0.72      0.82      0.77      4738
#
#     accuracy                           0.75      9424
#    macro avg       0.75      0.75      0.75      9424
# weighted avg       0.75      0.75      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7618845500848896
# [[3268 1429]
#  [ 815 3912]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.70      0.74      4697
#            1       0.73      0.83      0.78      4727
#
#     accuracy                           0.76      9424
#    macro avg       0.77      0.76      0.76      9424
# weighted avg       0.77      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7612478777589134
# [[3141 1461]
#  [ 789 4033]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.68      0.74      4602
#            1       0.73      0.84      0.78      4822
#
#     accuracy                           0.76      9424
#    macro avg       0.77      0.76      0.76      9424
# weighted avg       0.77      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7573217317487266
# [[3219 1473]
#  [ 814 3918]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.69      0.74      4692
#            1       0.73      0.83      0.77      4732
#
#     accuracy                           0.76      9424
#    macro avg       0.76      0.76      0.76      9424
# weighted avg       0.76      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7557300509337861
# [[3216 1480]
#  [ 822 3906]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.68      0.74      4696
#            1       0.73      0.83      0.77      4728
#
#     accuracy                           0.76      9424
#    macro avg       0.76      0.76      0.75      9424
# weighted avg       0.76      0.76      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.759125636672326
# [[3181 1507]
#  [ 763 3973]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.68      0.74      4688
#            1       0.72      0.84      0.78      4736
#
#     accuracy                           0.76      9424
#    macro avg       0.77      0.76      0.76      9424
# weighted avg       0.77      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7559422750424448
# [[3239 1482]
#  [ 818 3885]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.69      0.74      4721
#            1       0.72      0.83      0.77      4703
#
#     accuracy                           0.76      9424
#    macro avg       0.76      0.76      0.75      9424
# weighted avg       0.76      0.76      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7542444821731749
# [[3226 1484]
#  [ 832 3882]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.68      0.74      4710
#            1       0.72      0.82      0.77      4714
#
#     accuracy                           0.75      9424
#    macro avg       0.76      0.75      0.75      9424
# weighted avg       0.76      0.75      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7624151103565365
# [[3258 1474]
#  [ 765 3927]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.69      0.74      4732
#            1       0.73      0.84      0.78      4692
#
#     accuracy                           0.76      9424
#    macro avg       0.77      0.76      0.76      9424
# weighted avg       0.77      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.759125636672326
# [[3257 1477]
#  [ 793 3897]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.69      0.74      4734
#            1       0.73      0.83      0.77      4690
#
#     accuracy                           0.76      9424
#    macro avg       0.76      0.76      0.76      9424
# weighted avg       0.76      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7631578947368421
# [[3264 1454]
#  [ 778 3928]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.69      0.75      4718
#            1       0.73      0.83      0.78      4706
#
#     accuracy                           0.76      9424
#    macro avg       0.77      0.76      0.76      9424
# weighted avg       0.77      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7510611205432938
# [[3230 1543]
#  [ 803 3848]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.68      0.73      4773
#            1       0.71      0.83      0.77      4651
#
#     accuracy                           0.75      9424
#    macro avg       0.76      0.75      0.75      9424
# weighted avg       0.76      0.75      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7538200339558574
# [[3195 1465]
#  [ 855 3909]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.69      0.73      4660
#            1       0.73      0.82      0.77      4764
#
#     accuracy                           0.75      9424
#    macro avg       0.76      0.75      0.75      9424
# weighted avg       0.76      0.75      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7601867572156197
# [[3263 1451]
#  [ 809 3901]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.69      0.74      4714
#            1       0.73      0.83      0.78      4710
#
#     accuracy                           0.76      9424
#    macro avg       0.77      0.76      0.76      9424
# weighted avg       0.77      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.753713921901528
# [[3166 1499]
#  [ 822 3937]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.68      0.73      4665
#            1       0.72      0.83      0.77      4759
#
#     accuracy                           0.75      9424
#    macro avg       0.76      0.75      0.75      9424
# weighted avg       0.76      0.75      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7623089983022071
# [[3281 1435]
#  [ 805 3903]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.70      0.75      4716
#            1       0.73      0.83      0.78      4708
#
#     accuracy                           0.76      9424
#    macro avg       0.77      0.76      0.76      9424
# weighted avg       0.77      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7568972835314092
# [[3244 1491]
#  [ 800 3889]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.69      0.74      4735
#            1       0.72      0.83      0.77      4689
#
#     accuracy                           0.76      9424
#    macro avg       0.76      0.76      0.76      9424
# weighted avg       0.76      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7658106960950763
# [[3255 1464]
#  [ 743 3962]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.69      0.75      4719
#            1       0.73      0.84      0.78      4705
#
#     accuracy                           0.77      9424
#    macro avg       0.77      0.77      0.76      9424
# weighted avg       0.77      0.77      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7550933786078099
# [[3248 1511]
#  [ 797 3868]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.68      0.74      4759
#            1       0.72      0.83      0.77      4665
#
#     accuracy                           0.76      9424
#    macro avg       0.76      0.76      0.75      9424
# weighted avg       0.76      0.76      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7532894736842105
# [[3223 1522]
#  [ 803 3876]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.68      0.73      4745
#            1       0.72      0.83      0.77      4679
#
#     accuracy                           0.75      9424
#    macro avg       0.76      0.75      0.75      9424
# weighted avg       0.76      0.75      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7546689303904923
# [[3211 1491]
#  [ 821 3901]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.68      0.74      4702
#            1       0.72      0.83      0.77      4722
#
#     accuracy                           0.75      9424
#    macro avg       0.76      0.75      0.75      9424
# weighted avg       0.76      0.75      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7625212224108658
# [[3255 1493]
#  [ 745 3931]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.69      0.74      4748
#            1       0.72      0.84      0.78      4676
#
#     accuracy                           0.76      9424
#    macro avg       0.77      0.76      0.76      9424
# weighted avg       0.77      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7561544991511036
# [[3198 1488]
#  [ 810 3928]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.68      0.74      4686
#            1       0.73      0.83      0.77      4738
#
#     accuracy                           0.76      9424
#    macro avg       0.76      0.76      0.75      9424
# weighted avg       0.76      0.76      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7579584040747029
# [[3213 1456]
#  [ 825 3930]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.69      0.74      4669
#            1       0.73      0.83      0.78      4755
#
#     accuracy                           0.76      9424
#    macro avg       0.76      0.76      0.76      9424
# weighted avg       0.76      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7558361629881154
# [[3213 1512]
#  [ 789 3910]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.68      0.74      4725
#            1       0.72      0.83      0.77      4699
#
#     accuracy                           0.76      9424
#    macro avg       0.76      0.76      0.75      9424
# weighted avg       0.76      0.76      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7541383701188455
# [[3186 1515]
#  [ 802 3921]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.68      0.73      4701
#            1       0.72      0.83      0.77      4723
#
#     accuracy                           0.75      9424
#    macro avg       0.76      0.75      0.75      9424
# weighted avg       0.76      0.75      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7598684210526315
# [[3244 1447]
#  [ 816 3917]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.69      0.74      4691
#            1       0.73      0.83      0.78      4733
#
#     accuracy                           0.76      9424
#    macro avg       0.76      0.76      0.76      9424
# weighted avg       0.76      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7510611205432938
# [[3236 1539]
#  [ 807 3842]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.68      0.73      4775
#            1       0.71      0.83      0.77      4649
#
#     accuracy                           0.75      9424
#    macro avg       0.76      0.75      0.75      9424
# weighted avg       0.76      0.75      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7533955857385399
# [[3176 1504]
#  [ 820 3924]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.68      0.73      4680
#            1       0.72      0.83      0.77      4744
#
#     accuracy                           0.75      9424
#    macro avg       0.76      0.75      0.75      9424
# weighted avg       0.76      0.75      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7508488964346349
# [[3232 1564]
#  [ 784 3844]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.67      0.73      4796
#            1       0.71      0.83      0.77      4628
#
#     accuracy                           0.75      9424
#    macro avg       0.76      0.75      0.75      9424
# weighted avg       0.76      0.75      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7630517826825127
# [[3297 1443]
#  [ 790 3894]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.70      0.75      4740
#            1       0.73      0.83      0.78      4684
#
#     accuracy                           0.76      9424
#    macro avg       0.77      0.76      0.76      9424
# weighted avg       0.77      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7448005093378608
# [[3120 1510]
#  [ 895 3899]]
#               precision    recall  f1-score   support
#
#            0       0.78      0.67      0.72      4630
#            1       0.72      0.81      0.76      4794
#
#     accuracy                           0.74      9424
#    macro avg       0.75      0.74      0.74      9424
# weighted avg       0.75      0.74      0.74      9424
#
# Accuracy score of Logistic Regression is:
# 0.7614601018675722
# [[3234 1458]
#  [ 790 3942]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.69      0.74      4692
#            1       0.73      0.83      0.78      4732
#
#     accuracy                           0.76      9424
#    macro avg       0.77      0.76      0.76      9424
# weighted avg       0.77      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7571095076400679
# [[3223 1488]
#  [ 801 3912]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.68      0.74      4711
#            1       0.72      0.83      0.77      4713
#
#     accuracy                           0.76      9424
#    macro avg       0.76      0.76      0.76      9424
# weighted avg       0.76      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7547750424448217
# [[3203 1463]
#  [ 848 3910]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.69      0.73      4666
#            1       0.73      0.82      0.77      4758
#
#     accuracy                           0.75      9424
#    macro avg       0.76      0.75      0.75      9424
# weighted avg       0.76      0.75      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7592317487266553
# [[3225 1441]
#  [ 828 3930]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.69      0.74      4666
#            1       0.73      0.83      0.78      4758
#
#     accuracy                           0.76      9424
#    macro avg       0.76      0.76      0.76      9424
# weighted avg       0.76      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7560483870967742
# [[3239 1468]
#  [ 831 3886]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.69      0.74      4707
#            1       0.73      0.82      0.77      4717
#
#     accuracy                           0.76      9424
#    macro avg       0.76      0.76      0.75      9424
# weighted avg       0.76      0.76      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.759974533106961
# [[3302 1503]
#  [ 759 3860]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.69      0.74      4805
#            1       0.72      0.84      0.77      4619
#
#     accuracy                           0.76      9424
#    macro avg       0.77      0.76      0.76      9424
# weighted avg       0.77      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7554117147707979
# [[3274 1493]
#  [ 812 3845]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.69      0.74      4767
#            1       0.72      0.83      0.77      4657
#
#     accuracy                           0.76      9424
#    macro avg       0.76      0.76      0.75      9424
# weighted avg       0.76      0.76      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7522283531409168
# [[3223 1499]
#  [ 836 3866]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.68      0.73      4722
#            1       0.72      0.82      0.77      4702
#
#     accuracy                           0.75      9424
#    macro avg       0.76      0.75      0.75      9424
# weighted avg       0.76      0.75      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7612478777589134
# [[3213 1436]
#  [ 814 3961]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.69      0.74      4649
#            1       0.73      0.83      0.78      4775
#
#     accuracy                           0.76      9424
#    macro avg       0.77      0.76      0.76      9424
# weighted avg       0.77      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7560483870967742
# [[3241 1472]
#  [ 827 3884]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.69      0.74      4713
#            1       0.73      0.82      0.77      4711
#
#     accuracy                           0.76      9424
#    macro avg       0.76      0.76      0.75      9424
# weighted avg       0.76      0.76      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7530772495755518
# [[3200 1515]
#  [ 812 3897]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.68      0.73      4715
#            1       0.72      0.83      0.77      4709
#
# ...
#
#     accuracy                           0.76      9424
#    macro avg       0.76      0.76      0.76      9424
# weighted avg       0.76      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7618845500848896
# [[3263 1439]
#  [ 805 3917]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.69      0.74      4702
#            1       0.73      0.83      0.78      4722
#
#     accuracy                           0.76      9424
#    macro avg       0.77      0.76      0.76      9424
# weighted avg       0.77      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7570033955857386
# [[3221 1461]
#  [ 829 3913]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.69      0.74      4682
#            1       0.73      0.83      0.77      4742
#
#     accuracy                           0.76      9424
#    macro avg       0.76      0.76      0.76      9424
# weighted avg       0.76      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7568972835314092
# [[3228 1494]
#  [ 797 3905]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.68      0.74      4722
#            1       0.72      0.83      0.77      4702
#
#     accuracy                           0.76      9424
#    macro avg       0.76      0.76      0.76      9424
# weighted avg       0.76      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7580645161290323
# [[3240 1426]
#  [ 854 3904]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.69      0.74      4666
#            1       0.73      0.82      0.77      4758
#
#     accuracy                           0.76      9424
#    macro avg       0.76      0.76      0.76      9424
# weighted avg       0.76      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7574278438030561
# [[3254 1473]
#  [ 813 3884]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.69      0.74      4727
#            1       0.73      0.83      0.77      4697
#
#     accuracy                           0.76      9424
#    macro avg       0.76      0.76      0.76      9424
# weighted avg       0.76      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7606112054329371
# [[3238 1442]
#  [ 814 3930]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.69      0.74      4680
#            1       0.73      0.83      0.78      4744
#
#     accuracy                           0.76      9424
#    macro avg       0.77      0.76      0.76      9424
# weighted avg       0.77      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7633701188455009
# [[3260 1412]
#  [ 818 3934]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.70      0.75      4672
#            1       0.74      0.83      0.78      4752
#
#     accuracy                           0.76      9424
#    macro avg       0.77      0.76      0.76      9424
# weighted avg       0.77      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7522283531409168
# [[3257 1530]
#  [ 805 3832]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.68      0.74      4787
#            1       0.71      0.83      0.77      4637
#
#     accuracy                           0.75      9424
#    macro avg       0.76      0.75      0.75      9424
# weighted avg       0.76      0.75      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7580645161290323
# [[3184 1486]
#  [ 794 3960]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.68      0.74      4670
#            1       0.73      0.83      0.78      4754
#
#     accuracy                           0.76      9424
#    macro avg       0.76      0.76      0.76      9424
# weighted avg       0.76      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7570033955857386
# [[3181 1475]
#  [ 815 3953]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.68      0.74      4656
#            1       0.73      0.83      0.78      4768
#
#     accuracy                           0.76      9424
#    macro avg       0.76      0.76      0.76      9424
# weighted avg       0.76      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.759125636672326
# [[3270 1445]
#  [ 825 3884]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.69      0.74      4715
#            1       0.73      0.82      0.77      4709
#
#     accuracy                           0.76      9424
#    macro avg       0.76      0.76      0.76      9424
# weighted avg       0.76      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7555178268251274
# [[3190 1539]
#  [ 765 3930]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.67      0.73      4729
#            1       0.72      0.84      0.77      4695
#
#     accuracy                           0.76      9424
#    macro avg       0.76      0.76      0.75      9424
# weighted avg       0.76      0.76      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7414049235993209
# [[3150 1599]
#  [ 838 3837]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.66      0.72      4749
#            1       0.71      0.82      0.76      4675
#
#     accuracy                           0.74      9424
#    macro avg       0.75      0.74      0.74      9424
# weighted avg       0.75      0.74      0.74      9424
#
# Accuracy score of Logistic Regression is:
# 0.75
# [[3255 1511]
#  [ 845 3813]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.68      0.73      4766
#            1       0.72      0.82      0.76      4658
#
#     accuracy                           0.75      9424
#    macro avg       0.76      0.75      0.75      9424
# weighted avg       0.76      0.75      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7551994906621392
# [[3182 1493]
#  [ 814 3935]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.68      0.73      4675
#            1       0.72      0.83      0.77      4749
#
#     accuracy                           0.76      9424
#    macro avg       0.76      0.75      0.75      9424
# weighted avg       0.76      0.76      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7557300509337861
# [[3244 1460]
#  [ 842 3878]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.69      0.74      4704
#            1       0.73      0.82      0.77      4720
#
#     accuracy                           0.76      9424
#    macro avg       0.76      0.76      0.75      9424
# weighted avg       0.76      0.76      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7631578947368421
# [[3288 1448]
#  [ 784 3904]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.69      0.75      4736
#            1       0.73      0.83      0.78      4688
#
#     accuracy                           0.76      9424
#    macro avg       0.77      0.76      0.76      9424
# weighted avg       0.77      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7633701188455009
# [[3267 1391]
#  [ 839 3927]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.70      0.75      4658
#            1       0.74      0.82      0.78      4766
#
#     accuracy                           0.76      9424
#    macro avg       0.77      0.76      0.76      9424
# weighted avg       0.77      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7550933786078099
# [[3223 1497]
#  [ 811 3893]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.68      0.74      4720
#            1       0.72      0.83      0.77      4704
#
#     accuracy                           0.76      9424
#    macro avg       0.76      0.76      0.75      9424
# weighted avg       0.76      0.76      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7571095076400679
# [[3248 1475]
#  [ 814 3887]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.69      0.74      4723
#            1       0.72      0.83      0.77      4701
#
#     accuracy                           0.76      9424
#    macro avg       0.76      0.76      0.76      9424
# weighted avg       0.76      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7580645161290323
# [[3193 1462]
#  [ 818 3951]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.69      0.74      4655
#            1       0.73      0.83      0.78      4769
#
#     accuracy                           0.76      9424
#    macro avg       0.76      0.76      0.76      9424
# weighted avg       0.76      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7525466893039049
# [[3168 1494]
#  [ 838 3924]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.68      0.73      4662
#            1       0.72      0.82      0.77      4762
#
#     accuracy                           0.75      9424
#    macro avg       0.76      0.75      0.75      9424
# weighted avg       0.76      0.75      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7672962648556876
# [[3323 1415]
#  [ 778 3908]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.70      0.75      4738
#            1       0.73      0.83      0.78      4686
#
#     accuracy                           0.77      9424
#    macro avg       0.77      0.77      0.77      9424
# weighted avg       0.77      0.77      0.77      9424
#
# Accuracy score of Logistic Regression is:
# 0.7547750424448217
# [[3257 1476]
#  [ 835 3856]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.69      0.74      4733
#            1       0.72      0.82      0.77      4691
#
#     accuracy                           0.75      9424
#    macro avg       0.76      0.76      0.75      9424
# weighted avg       0.76      0.75      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7593378607809848
# [[3261 1450]
#  [ 818 3895]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.69      0.74      4711
#            1       0.73      0.83      0.77      4713
#
#     accuracy                           0.76      9424
#    macro avg       0.76      0.76      0.76      9424
# weighted avg       0.76      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7561544991511036
# [[3220 1490]
#  [ 808 3906]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.68      0.74      4710
#            1       0.72      0.83      0.77      4714
#
#     accuracy                           0.76      9424
#    macro avg       0.76      0.76      0.75      9424
# weighted avg       0.76      0.76      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7620967741935484
# [[3224 1468]
#  [ 774 3958]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.69      0.74      4692
#            1       0.73      0.84      0.78      4732
#
#     accuracy                           0.76      9424
#    macro avg       0.77      0.76      0.76      9424
# weighted avg       0.77      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7510611205432938
# [[3216 1574]
#  [ 772 3862]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.67      0.73      4790
#            1       0.71      0.83      0.77      4634
#
#     accuracy                           0.75      9424
#    macro avg       0.76      0.75      0.75      9424
# weighted avg       0.76      0.75      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7559422750424448
# [[3253 1489]
#  [ 811 3871]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.69      0.74      4742
#            1       0.72      0.83      0.77      4682
#
#     accuracy                           0.76      9424
#    macro avg       0.76      0.76      0.75      9424
# weighted avg       0.76      0.76      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7600806451612904
# [[3277 1453]
#  [ 808 3886]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.69      0.74      4730
#            1       0.73      0.83      0.77      4694
#
#     accuracy                           0.76      9424
#    macro avg       0.77      0.76      0.76      9424
# weighted avg       0.77      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7561544991511036
# [[3166 1500]
#  [ 798 3960]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.68      0.73      4666
#            1       0.73      0.83      0.78      4758
#
#     accuracy                           0.76      9424
#    macro avg       0.76      0.76      0.75      9424
# weighted avg       0.76      0.76      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.756578947368421
# [[3205 1489]
#  [ 805 3925]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.68      0.74      4694
#            1       0.72      0.83      0.77      4730
#
#     accuracy                           0.76      9424
#    macro avg       0.76      0.76      0.76      9424
# weighted avg       0.76      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7596561969439728
# [[3263 1424]
#  [ 841 3896]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.70      0.74      4687
#            1       0.73      0.82      0.77      4737
#
#     accuracy                           0.76      9424
#    macro avg       0.76      0.76      0.76      9424
# weighted avg       0.76      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7606112054329371
# [[3170 1477]
#  [ 779 3998]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.68      0.74      4647
#            1       0.73      0.84      0.78      4777
#
#     accuracy                           0.76      9424
#    macro avg       0.77      0.76      0.76      9424
# weighted avg       0.77      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7595500848896435
# [[3254 1488]
#  [ 778 3904]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.69      0.74      4742
#            1       0.72      0.83      0.78      4682
#
#     accuracy                           0.76      9424
#    macro avg       0.77      0.76      0.76      9424
# weighted avg       0.77      0.76      0.76      9424
#
# Accuracy score of Logistic Regression is:
# 0.7512733446519525
# [[3220 1543]
#  [ 801 3860]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.68      0.73      4763
#            1       0.71      0.83      0.77      4661
#
#     accuracy                           0.75      9424
#    macro avg       0.76      0.75      0.75      9424
# weighted avg       0.76      0.75      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7560483870967742
# [[3210 1525]
#  [ 774 3915]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.68      0.74      4735
#            1       0.72      0.83      0.77      4689
#
#     accuracy                           0.76      9424
#    macro avg       0.76      0.76      0.75      9424
# weighted avg       0.76      0.76      0.75      9424
#
# Accuracy score of Logistic Regression is:
# 0.7592317487266553
# [[3290 1555]
#  [ 714 3865]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.68      0.74      4845
#            1       0.71      0.84      0.77      4579
#
#     accuracy                           0.76      9424
#    macro avg       0.77      0.76      0.76      9424
# weighted avg       0.77      0.76      0.76      9424
#
# Best accuracy is 0.7672962648556876 on Random_state 184

# %% [markdown]
# Best accuracy is 0.7672962648556876 on Random_state 184

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.22,random_state=184)
lm=LogisticRegression()
lm.fit(x_train,y_train)
pred=lm.predict(x_test)
print('Accuracy score of Logistic Regression','is:')
accu_score=accuracy_score(y_test,pred)
print(accuracy_score(y_test,pred))
print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# Accuracy score of Logistic Regression is:
# 0.7672962648556876
# [[3323 1415]
#  [ 778 3908]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.70      0.75      4738
#            1       0.73      0.83      0.78      4686
#
#     accuracy                           0.77      9424
#    macro avg       0.77      0.77      0.77      9424
# weighted avg       0.77      0.77      0.77      9424

# %%
dtc=DecisionTreeClassifier()
dtc.fit(x_train,y_train)
preddtc=dtc.predict(x_test)
print('Accuracy score of DecisionTreeClassifier','is:')
accu_score=accuracy_score(y_test,preddtc)
print(accuracy_score(y_test,preddtc))
print(confusion_matrix(y_test,preddtc))
print(classification_report(y_test,preddtc))
# Out:
# Accuracy score of DecisionTreeClassifier is:
# 0.8623726655348047
# [[4038  700]
#  [ 597 4089]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.85      0.86      4738
#            1       0.85      0.87      0.86      4686
#
#     accuracy                           0.86      9424
#    macro avg       0.86      0.86      0.86      9424
# weighted avg       0.86      0.86      0.86      9424

# %%
knn=KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train,y_train)
predknn=knn.predict(x_test)
print('Accuracy score of knn','is:')
accu_score=accuracy_score(y_test,pred)
print(accuracy_score(y_test,pred))
print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# Accuracy score of knn is:
# 0.7672962648556876
# [[3323 1415]
#  [ 778 3908]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.70      0.75      4738
#            1       0.73      0.83      0.78      4686
#
#     accuracy                           0.77      9424
#    macro avg       0.77      0.77      0.77      9424
# weighted avg       0.77      0.77      0.77      9424

# %%
svm=SVC()
svm.fit(x_train,y_train)
predsvc=svm.predict(x_test)
print('Accuracy score of svm','is:')
accu_score=accuracy_score(y_test,predsvc)
print(accuracy_score(y_test,predsvc))
print(confusion_matrix(y_test,predsvc))
print(classification_report(y_test,predsvc))
# Out:
# Accuracy score of svm is:
# 0.8331918505942275
# [[3596 1142]
#  [ 430 4256]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.76      0.82      4738
#            1       0.79      0.91      0.84      4686
#
#     accuracy                           0.83      9424
#    macro avg       0.84      0.83      0.83      9424
# weighted avg       0.84      0.83      0.83      9424

# %%
bnb=GaussianNB()
bnb.fit(x_train,y_train)
predbnb=bnb.predict(x_test)
print('Accuracy score of BinomialNB','is:')
accu_score=accuracy_score(y_test,predbnb)
print(accuracy_score(y_test,predbnb))
print(confusion_matrix(y_test,predbnb))
print(classification_report(y_test,predbnb))
# Out:
# Accuracy score of BinomialNB is:
# 0.783955857385399
# [[3620 1118]
#  [ 918 3768]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.76      0.78      4738
#            1       0.77      0.80      0.79      4686
#
#     accuracy                           0.78      9424
#    macro avg       0.78      0.78      0.78      9424
# weighted avg       0.78      0.78      0.78      9424

# %%
from sklearn.ensemble import RandomForestClassifier

rf=RandomForestClassifier()
rf.fit(x_train,y_train)
predrf=rf.predict(x_test)
print('Accuracy score of RandomForestClassifier','is:')
accu_score=accuracy_score(y_test,predrf)
print(accuracy_score(y_test,predrf))
print(confusion_matrix(y_test,predrf))
print(classification_report(y_test,predrf))
# Out:
# Accuracy score of RandomForestClassifier is:
# 0.9003607809847198
# [[4234  504]
#  [ 435 4251]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.89      0.90      4738
#            1       0.89      0.91      0.90      4686
#
#     accuracy                           0.90      9424
#    macro avg       0.90      0.90      0.90      9424
# weighted avg       0.90      0.90      0.90      9424

# %%
from sklearn.ensemble import AdaBoostClassifier

ad=AdaBoostClassifier()
ad.fit(x_train,y_train)
predad=ad.predict(x_test)
print('Accuracy score of AdaBoostClassifier','is:')
accu_score=accuracy_score(y_test,predad)
print(accuracy_score(y_test,predad))
print(confusion_matrix(y_test,predad))
print(classification_report(y_test,predad))
# Out:
# Accuracy score of AdaBoostClassifier is:
# 0.8642826825127334
# [[3973  765]
#  [ 514 4172]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.84      0.86      4738
#            1       0.85      0.89      0.87      4686
#
#     accuracy                           0.86      9424
#    macro avg       0.87      0.86      0.86      9424
# weighted avg       0.87      0.86      0.86      9424

# %% [markdown]
# Random Forest Classifier is the best algorithm.

# %% [markdown]
# # Cross - Validation Scores

# %%
from sklearn.model_selection import cross_val_score
rfscores=cross_val_score(rf,x,y,cv=5)
print(rfscores)
print(rfscores.mean(),rfscores.std())
# Out:
# [0.80648926 0.87778686 0.9234271  0.9259951  0.92529474]
# 0.8917986111996644 0.04640208151983787

# %%
list1=[0.900679117147708]
list2=[0.8920320896733465]
difference=[]
zip_object = zip(list1, list2)
for list1_i, list2_i in zip_object:
    difference.append(list1_i-list2_i)


print(difference)
# Out:
# [0.008647027474361524]

# %% [markdown]
# As the difference between accuracy scores and cross validation scores of Random Forest Classifier is approximately 0%. So,
# It is verified that Random Forest Classifier is the best algorithm for this model with accuracy of 90.556 % .

# %% [markdown]
# # Hyper Parameter Tuning

# %%
rf=RandomForestClassifier()
grid_param={'criterion':['gini','entropy'],'max_features':['auto','sqrt','log2'],'n_estimators':[25,50,75,100],'max_depth':[None,int]}
gd_sr=GridSearchCV(estimator=rf,param_grid=grid_param,scoring='accuracy',cv=5)
gd_sr.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [None, <class 'int'>],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [25, 50, 75, 100]},
#              scoring='accuracy')

# %%
gd_sr.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'log2',
#  'n_estimators': 100}

# %%
rf=RandomForestClassifier(criterion= 'gini',
 max_depth=None,
 max_features= 'log2',
 n_estimators= 100)
rf.fit(x_train,y_train)
predrf=rf.predict(x_test)
print('Accuracy score of RandomForestClassifier','is:')
accu_score=accuracy_score(y_test,predrf)
print(accuracy_score(y_test,predrf))
print(confusion_matrix(y_test,predrf))
print(classification_report(y_test,predrf))
# Out:
# Accuracy score of RandomForestClassifier is:
# 0.9007852292020373
# [[4236  502]
#  [ 433 4253]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.89      0.90      4738
#            1       0.89      0.91      0.90      4686
#
#     accuracy                           0.90      9424
#    macro avg       0.90      0.90      0.90      9424
# weighted avg       0.90      0.90      0.90      9424

# %% [markdown]
# Accuracy of Random Forest Classifier has changed from 90.036 % to 90.078 % with hyper parameter tuning.

# %% [markdown]
# # AOC - ROC Curve

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

# %%
y_pred_prob=rf.predict_proba(x_test)[:,1]

# %%
y_pred_prob
# Out:
# array([0.8 , 0.  , 0.02, ..., 0.  , 0.  , 0.98])

# %%
fpr,tpr,thresholds=roc_curve(y_test,y_pred_prob)

# %%
fpr
# Out:
# array([0.00000000e+00, 6.33178556e-04, 1.05529759e-03, 1.05529759e-03,
#        1.05529759e-03, 1.68847615e-03, 2.11059519e-03, 3.16589278e-03,
#        4.01013086e-03, 5.69860701e-03, 6.75390460e-03, 8.02026171e-03,
#        9.28661883e-03, 1.16082735e-02, 1.35078092e-02, 1.54073449e-02,
#        1.64626425e-02, 1.64626425e-02, 1.73068805e-02, 1.98395948e-02,
#        2.08948924e-02, 2.17391304e-02, 2.40607851e-02, 2.80709160e-02,
#        3.10257493e-02, 3.25031659e-02, 3.35584635e-02, 3.69354158e-02,
#        3.98902491e-02, 3.98902491e-02, 4.32672014e-02, 4.47446180e-02,
#        4.64330941e-02, 4.91768679e-02, 5.06542845e-02, 5.31869987e-02,
#        5.63528915e-02, 5.78303081e-02, 6.14183200e-02, 6.43731532e-02,
#        6.69058675e-02, 6.88054031e-02, 7.15491769e-02, 7.32376530e-02,
#        7.55593077e-02, 7.80920220e-02, 7.80920220e-02, 8.10468552e-02,
#        8.50569861e-02, 8.92781764e-02, 9.18108907e-02, 9.43436049e-02,
#        9.83537358e-02, 1.01730688e-01, 1.06373997e-01, 1.10384128e-01,
#        1.12916843e-01, 1.16715914e-01, 1.22414521e-01, 1.27268890e-01,
#        1.31279021e-01, 1.36766568e-01, 1.43942592e-01, 1.49008020e-01,
#        1.54495568e-01, 1.54706627e-01, 1.59560996e-01, 1.63571127e-01,
#        1.68425496e-01, 1.75601520e-01, 1.81300127e-01, 1.87842972e-01,
#        1.94807936e-01, 2.01350781e-01, 2.07260447e-01, 2.15913888e-01,
#        2.22878852e-01, 2.30054875e-01, 2.35331363e-01, 2.44195863e-01,
#        2.52849304e-01, 2.62980160e-01, 2.72688898e-01, 2.79653862e-01,
#        2.87040946e-01, 2.92950612e-01, 3.02237231e-01, 3.09413255e-01,
#        3.20177290e-01, 3.30730266e-01, 3.41283242e-01, 3.49725623e-01,
#        3.61122837e-01, 3.74630646e-01, 3.87927396e-01, 4.03123681e-01,
#        4.17053609e-01, 4.34149430e-01, 4.52300549e-01, 4.75306036e-01,
#        4.97045167e-01, 5.21739130e-01, 5.53398058e-01, 5.89911355e-01,
#        6.37188687e-01, 7.14436471e-01, 1.00000000e+00])

# %%
tpr
# Out:
# array([0.        , 0.21895006, 0.31306018, 0.37387964, 0.37409304,
#        0.42445583, 0.4605207 , 0.49039693, 0.51920615, 0.54204012,
#        0.56850192, 0.58920188, 0.60734102, 0.62398634, 0.64212548,
#        0.66111822, 0.67755015, 0.67776355, 0.69120785, 0.70550576,
#        0.71809646, 0.72791293, 0.73986342, 0.7496799 , 0.75885617,
#        0.76803244, 0.7761417 , 0.78382416, 0.79150662, 0.79172002,
#        0.79833547, 0.80793854, 0.81391379, 0.82159624, 0.82650448,
#        0.83269313, 0.83674776, 0.84400341, 0.85019206, 0.8546735 ,
#        0.86043534, 0.86342296, 0.8681178 , 0.87174563, 0.87580026,
#        0.87857448, 0.87878788, 0.8813487 , 0.88625694, 0.88860435,
#        0.89201878, 0.8945796 , 0.90012804, 0.90290226, 0.90717029,
#        0.90909091, 0.91314554, 0.91655997, 0.92018779, 0.92253521,
#        0.92381562, 0.92616304, 0.92915066, 0.93235169, 0.9346991 ,
#        0.9346991 , 0.93576611, 0.93854033, 0.94024755, 0.94195476,
#        0.94579599, 0.9475032 , 0.94835681, 0.95113103, 0.95582586,
#        0.95774648, 0.95945369, 0.9611609 , 0.96329492, 0.96606914,
#        0.96777636, 0.96948357, 0.97204439, 0.97439181, 0.97545881,
#        0.97716603, 0.97844644, 0.98036705, 0.98164746, 0.98420828,
#        0.98570209, 0.9867691 , 0.98783611, 0.98868971, 0.98954332,
#        0.99103713, 0.99167734, 0.99295775, 0.99338455, 0.99359795,
#        0.99445156, 0.99466496, 0.99551857, 0.99722578, 0.99807939,
#        0.99893299, 1.        ])

# %%
thresholds
# Out:
# array([2.        , 1.        , 0.99      , 0.98      , 0.97666667,
#        0.97      , 0.96      , 0.95      , 0.94      , 0.93      ,
#        0.92      , 0.91      , 0.9       , 0.89      , 0.88      ,
#        0.87      , 0.86      , 0.85166667, 0.85      , 0.84      ,
#        0.83      , 0.82      , 0.81      , 0.8       , 0.79      ,
#        0.78      , 0.77      , 0.76      , 0.75      , 0.7425    ,
#        0.74      , 0.73      , 0.72      , 0.71      , 0.7       ,
#        0.69      , 0.68      , 0.67      , 0.66      , 0.65      ,
#        0.64      , 0.63      , 0.62      , 0.61      , 0.6       ,
#        0.59      , 0.58970238, 0.58      , 0.57      , 0.56      ,
#        0.55      , 0.54      , 0.53      , 0.52      , 0.51      ,
#        0.5       , 0.49      , 0.48      , 0.47      , 0.46      ,
#        0.45      , 0.44      , 0.43      , 0.42      , 0.41      ,
#        0.40333333, 0.4       , 0.39      , 0.38      , 0.37      ,
#        0.36      , 0.35      , 0.34      , 0.33      , 0.32      ,
#        0.31      , 0.3       , 0.29      , 0.28      , 0.27      ,
#        0.26      , 0.25      , 0.24      , 0.23      , 0.22      ,
#        0.21      , 0.2       , 0.19      , 0.18      , 0.17      ,
#        0.16      , 0.15      , 0.14      , 0.13      , 0.12      ,
#        0.11      , 0.1       , 0.09      , 0.08      , 0.07      ,
#        0.06      , 0.05      , 0.04      , 0.03      , 0.02      ,
#        0.01      , 0.        ])

# %%
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr,label='Random Forest')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('Random Forest Classifier')
plt.show()

# %% [markdown]
# Observations :-
#
# 1. As the line is moving towards 1, so we can conclude that we have developed good model.

# %% [markdown]
# # Saving the model

# %%
import joblib

# %%
joblib.dump(rf,"rf_census_income.obj")
# Out:
# ['rf_census_income.obj']
